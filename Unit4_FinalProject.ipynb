# %% [markdown]
# # Unit 4 Final Projects: Calculating evolutionary distance
#
# In this notebook you will compare the sequence of a particular gene from 3 different species to find out which two are most closely related.
#
# You will need to do the following:
# 1. Open and read in your files
# 2. Decide which sequences to compare (DNA, RNA, or protein), (you may have to look at all of them)
# 3. Write code that prints out the percent similarity of each pair of sequences
#
# Note: Percent similarity can be taken by the following formula: `similarites * 100 / length of the shortest sequence`

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
turtle = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/2a_CYTB_DNA.txt").read()
chicken = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/2b_CYTB_DNA.txt").read()
alligator = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/2c_CYTB_DNA.txt").read()

# %%
a = turtle
b = alligator
c = chicken

# %%
numSimilarities = 0

#for loop to iterate through both lists
for a, i in enumerate(turtle):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if alligator [a] == i:
    numSimilarities += 1
print(numSimilarities)
# Out:
# 792

# %%
numSimilarities = 0

#for loop to iterate through both lists
for a, i in enumerate(turtle):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if chicken [c] == i:
    numSimilarities += 1
print(numSimilarities)
# Out:
# 349

# %%
numSimilarities = 0

#for loop to iterate through both lists
for c, i in enumerate(chicken):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if turtle [a] == i:
    numSimilarities += 1
print(numSimilarities)
# Out:
# 309

# %%
numSimilarities = 0
#for loop to iterate through both lists
for c, i in enumerate(chicken):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if alligator [b] == i:
    numSimilarities += 1
print(numSimilarities)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-8709dc761913> in <module>()
#       7 #compare each sequence usinf an if statement
#       8
# ----> 9   if alligator [b] == i:
#      10     numSimilarities += 1
#      11 print(numSimilarities)
#
# TypeError: string indices must be integers

# %%
numSimilarities = 0
#for loop to iterate through both lists
for c, i in enumerate(chicken):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if turtle [b] == i:
    numSimilarities += 1
print(numSimilarities)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-69f9874b2323> in <module>()
#       7 #compare each sequence usinf an if statement
#       8
# ----> 9   if turtle [b] == i:
#      10     numSimilarities += 1
#      11 print(numSimilarities)
#
# TypeError: string indices must be integers

# %% [markdown]
# ## Bonus Challenge
#
# Visualize your results! Choose a graph type that you think will communicate your conclusions effectively and create it using matplotlib:

# %%
#a = turtle
#b = chicken
#c = alligator

import matplotlib

# %% [markdown]
# ## Bonus Challenge 2
# If you finish your project and want to try a challenge, come up with a hypothesis about which of the following species are most closely related to humans (carp, chicken, chimp, dog, eel, elephant, frog, gorilla, macaque monkey, mouse, orangutan, pig). Write out a ranked list with the species you think is most related to humans at the top.
#
# Then calculate the percent difference between the hemoglobin amino acid sequences of humans and each species to find out how close you came to the right ranking!

# %%
# Oragutan, Chimpanzee, Macaque Monkey, Gorilla, Mouse, Frog, Dog, Chicken, Elephant, Pig, Eel, Carp

# %%
Oragutan = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Orangutan_hemoglobin (1).txt").read()
Carp = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Carp_hemoglobin.txt").read()
Human = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Human_hemoglobin.txt").read()
Dog = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Dog_hemoglobin.txt").read()
Eel = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Eel_hemoglobin.txt").read()
Macaque = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Eel_hemoglobin.txt").read()
Chimpanzee = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Chimp_hemoglobin.txt").read()
Pig = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Pig_hemoglobin.txt").read()
Mouse = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Mouse_hemoglobin.txt").read()
Chicken = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Chicken_hemoglobin.txt").read()
Elephant = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Elephant_hemoglobin.txt").read()
Frog = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Frog_hemoglobin.txt").read()
Gorilla = open("/content/drive/MyDrive/Colab Notebooks/BridgeUP/Gorilla_hemoglobin.txt").read()

# %%
#Human -> Orangutan
numSimilaritiesHO = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not similar 

#compare each sequence using an if statement

  if Oragutan [c] == i:
    numSimilaritiesHO += 1
print(numSimilaritiesHO)
# Out:
# 138

# %%
#Human -> Carp
numSimilaritiesHC = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Carp [c] == i:
    numSimilaritiesHC += 1
print(numSimilaritiesHC)
# Out:
# 30

# %%
#Humans -> Dog
numSimilaritiesHD = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Dog [c] == i:
    numSimilaritiesHD += 1
print(numSimilaritiesHD)
# Out:
# 118

# %%
#Humans -> Macaque
numSimilaritiesHM = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Macaque [c] == i:
    numSimilaritiesHM += 1
print(numSimilaritiesHC)
# Out:
# 28

# %%
#Humans -> Chimpanzee
numSimilaritiesHC = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Chimpanzee [c] == i:
    numSimilaritiesHC += 1
print(numSimilaritiesHC)
# Out:
# 141

# %%
#Humans -> Pig
numSimilaritiesHP = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Pig [c] == i:
    numSimilaritiesHP += 1
print(numSimilaritiesHP)
# Out:
# 119

# %%
#Humans -> Mouse
numSimilaritiesHMO = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Mouse [c] == i:
    numSimilaritiesHMO += 1
print(numSimilaritiesHMO)
# Out:
# 121

# %%
#Humans -> Chicken
numSimilaritiesHCH = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Chicken [c] == i:
    numSimilaritiesHCH += 1
print(numSimilaritiesHCH)
# Out:
# 99

# %%
#Humans -> Gorilla
numSimilaritiesHG = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Gorilla [c] == i:
    numSimilaritiesHG += 1
print(numSimilaritiesHG)
# Out:
# 140

# %%
#Humans -> Frog
numSimilaritiesHF = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Frog [c] == i:
    numSimilaritiesHF += 1
print(numSimilaritiesHF)
# Out:
# 81

# %%
#Humans -> Elephant
numSimilaritiesHE = 0
#for loop to iterate through both lists
for c, i in enumerate(Human):

# 1=checks for things that are not different

#compare each sequence usinf an if statement

  if Elephant [c] == i:
    numSimilaritiesHE += 1
print(numSimilaritiesHE)
# Out:
# 117

# %%
#Finding length of each sequence
len(Oragutan)
print(len(Oragutan))
len(Carp)
print(len(Carp))
len(Dog)
print(len(Dog))
len(Macaque)
print(len(Macaque))
len(Chimpanzee)
print(len(Chimpanzee))
len(Pig)
print(len(Pig))
len(Mouse)
print(len(Mouse))
len(Chicken)
print(len(Chicken))
len(Gorilla)
print(len(Gorilla))
len(Frog)
print(len(Frog))
len(Elephant)
print(len(Elephant))
len(Eel)
print(len(Eel))
# Out:
# 141
# 142
# 141
# 142
# 141
# 141
# 141
# 141
# 141
# 141
# 141
# 142

# %%
#Finding percent of similarity 
#similarity * 100 / length of the shortest sequence

#Human Oragutan Percent
percentHO = (numSimilaritiesHO * 100)/len(Oragutan)
print(percentHO)
percentHC = (numSimilaritiesHC * 100)/len(Oragutan)
print(percentHC)
percentHD = (numSimilaritiesHD * 100)/len(Oragutan)
print(percentHD)
percentHM = (numSimilaritiesHM * 100)/len(Oragutan)
print(percentHC)
percentHC = (numSimilaritiesHC * 100)/len(Oragutan)
print(percentHC)
percentHP = (numSimilaritiesHP * 100)/len(Oragutan)
print(percentHP)
percentHMO = (numSimilaritiesHMO * 100)/len(Oragutan)
print(percentHMO)
percentHCH = (numSimilaritiesHCH * 100)/len(Oragutan)
print(percentHCH)
percentHG = (numSimilaritiesHG * 100)/len(Oragutan)
print(percentHG)
percentHF = (numSimilaritiesHF * 100)/len(Oragutan)
print(percentHF)
percentHE = (numSimilaritiesHE * 100)/len(Oragutan)
print(percentHE)
# Out:
# 97.87234042553192
# 19.858156028368793
# 83.68794326241135
# 19.858156028368793
# 19.858156028368793
# 84.39716312056737
# 85.81560283687944
# 70.2127659574468
# 99.29078014184397
# 57.4468085106383
# 82.97872340425532

# %%
print("Human to Oragutan Similarity:" + str(percentHO))
print("Human to Carp Similarity:" + str(percentHC))
print("Human to Dog Similarity:" + str(percentHD))
print("Human to Chimpanzee Similarity:" + str(percentHC))
print("Human to Mice Similarity:" + str(percentHM))
print("Human to Oragutan Similarity:" + str(percentHC))
print("Human to Oragutan Similarity:" + str(percentHMO))
print("Human to Oragutan Similarity:" + str(percentHCH))
print("Human to Oragutan Similarity:" + str(percentHG))
print("Human to Oragutan Similarity:" + str(percentHF))
print("Human to Oragutan Similarity:" + str(percentHE))
# Out:
# Human to Oragutan Similarity:97.87234042553192
# Human to Oragutan Similarity:19.858156028368793
# Human to Oragutan Similarity:83.68794326241135
# Human to Oragutan Similarity:19.858156028368793
# Human to Oragutan Similarity:97.87234042553192
# Human to Oragutan Similarity:84.39716312056737
# Human to Oragutan Similarity:85.81560283687944
# Human to Oragutan Similarity:70.2127659574468
# Human to Oragutan Similarity:99.29078014184397
# Human to Oragutan Similarity:57.4468085106383
# Human to Oragutan Similarity:82.97872340425532

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax=fig.add_axes([0,1,1,1])
percents = []
